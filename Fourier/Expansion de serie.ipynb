# %% [markdown]
# <center><h3>Expansión de serie de Fourier</h3></center>

# %%
from IPython.display import HTML, Math, Latex, display
import numpy as np
import matplotlib.pyplot as plt
from sympy import *
from sympy.printing import latex
import math

a0 = (4*pi**2)/3
an = (4/n**2)
bn = (-4*pi/n)
expresion = an * cos(n*t) + bn * sin(n*t)
expansion = a0

def desmosify(e):
    return str(e).replace("**", "^").replace("pi", "π")

print("g=" + desmosify(a0))
for i in range(1, 20):
    next = expresion.subs(n, i)
    expansion = next + expansion
    print(desmosify(next))
    
print()
print("g=" + desmosify(expansion))


display(Latex("$$g(t) = {}$$".format(latex(expansion))))
# Out:
# g=4*π^2/3
# -4*π*sin(t) + 4*cos(t)
# -2*π*sin(2*t) + cos(2*t)
# -4*π*sin(3*t)/3 + 4*cos(3*t)/9
# -π*sin(4*t) + cos(4*t)/4
# -4*π*sin(5*t)/5 + 4*cos(5*t)/25
# -2*π*sin(6*t)/3 + cos(6*t)/9
# -4*π*sin(7*t)/7 + 4*cos(7*t)/49
# -π*sin(8*t)/2 + cos(8*t)/16
# -4*π*sin(9*t)/9 + 4*cos(9*t)/81
# -2*π*sin(10*t)/5 + cos(10*t)/25
# -4*π*sin(11*t)/11 + 4*cos(11*t)/121
# -π*sin(12*t)/3 + cos(12*t)/36
# -4*π*sin(13*t)/13 + 4*cos(13*t)/169
# -2*π*sin(14*t)/7 + cos(14*t)/49
# -4*π*sin(15*t)/15 + 4*cos(15*t)/225
# -π*sin(16*t)/4 + cos(16*t)/64
# -4*π*sin(17*t)/17 + 4*cos(17*t)/289
# -2*π*sin(18*t)/9 + cos(18*t)/81
# -4*π*sin(19*t)/19 + 4*cos(19*t)/361
#
# ...
