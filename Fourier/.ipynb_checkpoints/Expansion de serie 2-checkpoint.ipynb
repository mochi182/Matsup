# %% [markdown]
# <h3>Expansión de serie de Fourier</h3>

# %%
from IPython.display import HTML, Math, Latex, display
from sympy import *
from sympy.printing import latex

n, t = symbols('n,t')

T = 2*pi
w = 1
a0 = 2*pi
an = 0
bn = -2/n
expresion = an * cos(n*w*t) + bn * sin(n*w*t)
expansion = a0/2

writeable_strs = ["$$g(t) = {}$$".format(latex(expansion))]
for i in range(10):
    next = expresion.subs(n, i+1)
    expansion = next + expansion
    writeable_strs.append("$${}$$".format(latex(next)))

# %% [markdown]
# Para copiar:

# %%
for i in writeable_strs:
    display(Latex(i))
# Out:
# $$g(t) = \pi$$
# $$- 2 \sin{\left(t \right)}$$
# $$- \sin{\left(2 t \right)}$$
# $$- \frac{2 \sin{\left(3 t \right)}}{3}$$
# $$- \frac{\sin{\left(4 t \right)}}{2}$$
# $$- \frac{2 \sin{\left(5 t \right)}}{5}$$
# $$- \frac{\sin{\left(6 t \right)}}{3}$$
# $$- \frac{2 \sin{\left(7 t \right)}}{7}$$
# $$- \frac{\sin{\left(8 t \right)}}{4}$$
# $$- \frac{2 \sin{\left(9 t \right)}}{9}$$
# $$- \frac{\sin{\left(10 t \right)}}{5}$$

# %% [markdown]
# Para desmos:

# %%
def desmos_syntax(e):
    return str(e).replace("**", "^").replace("pi", "π")
desmos_str = "g=" + desmos_syntax(expansion)
print(desmos_str)
# Out:
# g=-2*sin(t) - sin(2*t) - 2*sin(3*t)/3 - sin(4*t)/2 - 2*sin(5*t)/5 - sin(6*t)/3 - 2*sin(7*t)/7 - sin(8*t)/4 - 2*sin(9*t)/9 - sin(10*t)/5 + π

# %% [markdown]
# Latex continuo:

# %%
latex_str = "$$g(t) = {}$$".format(latex(expansion))
display(Latex(latex_str))
# Out:
# $$g(t) = - 2 \sin{\left(t \right)} - \sin{\left(2 t \right)} - \frac{2 \sin{\left(3 t \right)}}{3} - \frac{\sin{\left(4 t \right)}}{2} - \frac{2 \sin{\left(5 t \right)}}{5} - \frac{\sin{\left(6 t \right)}}{3} - \frac{2 \sin{\left(7 t \right)}}{7} - \frac{\sin{\left(8 t \right)}}{4} - \frac{2 \sin{\left(9 t \right)}}{9} - \frac{\sin{\left(10 t \right)}}{5} + \pi$$
