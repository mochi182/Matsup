# %% [markdown]
# <h3>Expansión de serie de Fourier</h3>

# %%
from IPython.display import HTML, Math, Latex, display
import numpy as np
import matplotlib.pyplot as plt
from sympy import *
from sympy.printing import latex
import math

n, t = symbols('n,t')

T = 2*pi
w = 1
a0 = sinh(pi)/pi
an = (2*sinh(pi)*((-1)**n))/(pi*(1+n**2))
bn = (2*n*sinh(pi)*((-1)**n))/(pi*(1+n**2))
expresion = an * cos(n*w*t) + bn * sin(n*w*t)
expansion = a0

writeable_strs = ["$$g(t) = {}$$".format(latex(a0))]
for i in range(10):
    next = expresion.subs(n, i+1)
    expansion = next + expansion
    writeable_strs.append("$${}$$".format(latex(next)))

# %% [markdown]
# Para copiar:

# %%
for i in writeable_strs:
    display(Latex(i))
# Out:
# $$g(t) = \frac{\sinh{\left(\pi \right)}}{\pi}$$
# $$- \frac{\sin{\left(t \right)} \sinh{\left(\pi \right)}}{\pi} - \frac{\cos{\left(t \right)} \sinh{\left(\pi \right)}}{\pi}$$
# $$\frac{4 \sin{\left(2 t \right)} \sinh{\left(\pi \right)}}{5 \pi} + \frac{2 \cos{\left(2 t \right)} \sinh{\left(\pi \right)}}{5 \pi}$$
# $$- \frac{3 \sin{\left(3 t \right)} \sinh{\left(\pi \right)}}{5 \pi} - \frac{\cos{\left(3 t \right)} \sinh{\left(\pi \right)}}{5 \pi}$$
# $$\frac{8 \sin{\left(4 t \right)} \sinh{\left(\pi \right)}}{17 \pi} + \frac{2 \cos{\left(4 t \right)} \sinh{\left(\pi \right)}}{17 \pi}$$
# $$- \frac{5 \sin{\left(5 t \right)} \sinh{\left(\pi \right)}}{13 \pi} - \frac{\cos{\left(5 t \right)} \sinh{\left(\pi \right)}}{13 \pi}$$
# $$\frac{12 \sin{\left(6 t \right)} \sinh{\left(\pi \right)}}{37 \pi} + \frac{2 \cos{\left(6 t \right)} \sinh{\left(\pi \right)}}{37 \pi}$$
# ...

# %% [markdown]
# Para desmos:

# %%
def desmos_syntax(e):
    return str(e).replace("**", "^").replace("pi", "π")
desmos_str = "g=" + desmos_syntax(expansion)
print(desmos_str)
# Out:
# g=-sin(t)*sinh(π)/π + 4*sin(2*t)*sinh(π)/(5*π) - 3*sin(3*t)*sinh(π)/(5*π) + 8*sin(4*t)*sinh(π)/(17*π) - 5*sin(5*t)*sinh(π)/(13*π) + 12*sin(6*t)*sinh(π)/(37*π) - 7*sin(7*t)*sinh(π)/(25*π) + 16*sin(8*t)*sinh(π)/(65*π) - 9*sin(9*t)*sinh(π)/(41*π) + 20*sin(10*t)*sinh(π)/(101*π) - cos(t)*sinh(π)/π + 2*cos(2*t)*sinh(π)/(5*π) - cos(3*t)*sinh(π)/(5*π) + 2*cos(4*t)*sinh(π)/(17*π) - cos(5*t)*sinh(π)/(13*π) + 2*cos(6*t)*sinh(π)/(37*π) - cos(7*t)*sinh(π)/(25*π) + 2*cos(8*t)*sinh(π)/(65*π) - cos(9*t)*sinh(π)/(41*π) + 2*cos(10*t)*sinh(π)/(101*π) + sinh(π)/π

# %% [markdown]
# Latex continuo:

# %%
latex_str = "$$g(t) = {}$$".format(latex(expansion))
display(Latex(latex_str))
# Out:
# $$g(t) = - \frac{\sin{\left(t \right)} \sinh{\left(\pi \right)}}{\pi} + \frac{4 \sin{\left(2 t \right)} \sinh{\left(\pi \right)}}{5 \pi} - \frac{3 \sin{\left(3 t \right)} \sinh{\left(\pi \right)}}{5 \pi} + \frac{8 \sin{\left(4 t \right)} \sinh{\left(\pi \right)}}{17 \pi} - \frac{5 \sin{\left(5 t \right)} \sinh{\left(\pi \right)}}{13 \pi} + \frac{12 \sin{\left(6 t \right)} \sinh{\left(\pi \right)}}{37 \pi} - \frac{7 \sin{\left(7 t \right)} \sinh{\left(\pi \right)}}{25 \pi} + \frac{16 \sin{\left(8 t \right)} \sinh{\left(\pi \right)}}{65 \pi} - \frac{9 \sin{\left(9 t \right)} \sinh{\left(\pi \right)}}{41 \pi} + \frac{20 \sin{\left(10 t \right)} \sinh{\left(\pi \right)}}{101 \pi} - \frac{\cos{\left(t \right)} \sinh{\left(\pi \right)}}{\pi} + \frac{2 \cos{\left(2 t \right)} \sinh{\left(\pi \right)}}{5 \pi} - \frac{\cos{\left(3 t \right)} \sinh{\left(\pi \right)}}{5 \pi} + \frac{2 \cos{\left(4 t \right)} \sinh{\left(\pi \right)}}{17 \pi} - \frac{\cos{\left(5 t \right)} \sinh{\left(\pi \rig
# ...
